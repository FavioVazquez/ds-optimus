# %% [markdown]
# # US - Baby Names
#
# ## Introduction:
#
# We are going to use a subset of [US Baby Names from](https://www.kaggle.com/kaggle/us-baby-names) Kaggle.
#
# In the file it will be names from 2004 until 2014

# %%
# Import the necessary libraries
from optimus import Optimus
from pyspark.sql.functions import *
import pandas as pd
import numpy as np
op = Optimus()

# %% [markdown]
# # Import the dataset and assing baby_names

# %%
baby_names_pd = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv')

# %%
baby_names = op.spark.createDataFrame(baby_names_pd)

# %%
baby_names.describe().table()
# Out:
# <h1></h1>
#
#
#
#
#
# <div class="info_items">Viewing 5 of 5 rows / 8 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">summary</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Unnamed: 0</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Id</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Name</div>
#             <div class="data_type">4 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Year</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Gender</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">State</div>
#             <div class="data_type">7 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Count</div>
#             <div class="data_type">8 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='count'>count
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1016395'>1016395
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1016395'>1016395
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1016395'>1016395
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1016395'>1016395
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1016395'>1016395
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1016395'>1016395
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1016395'>1016395
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='mean'>mean
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2830990.4619178567'>2830990.4619178567
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2830991.4619178567'>2830991.4619178567
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Infinity'>Infinity
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2009.0531899507573'>2009.0531899507573
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='34.85012421351935'>34.85012421351935
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='stddev'>stddev
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1652475.6514804524'>1652475.6514804524
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='1652475.6514804524'>1652475.6514804524
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='NaN'>NaN
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='3.1382928281815494'>3.1382928281815494
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class="none "
#                  title='None'>None
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='97.3973464861767'>97.3973464861767
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='min'>min
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='11349'>11349
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='11350'>11350
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Aaban'>Aaban
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2004'>2004
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='F'>F
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='AK'>AK
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5'>5
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='max'>max
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5647425'>5647425
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5647426'>5647426
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Zyriah'>Zyriah
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2014'>2014
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='M'>M
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='WY'>WY
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='4167'>4167
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 5 of 5 rows / 8 columns</div>
# <div class="info_items">1 partition(s)</div>

# %% [markdown]
# # See the first 10 entries

# %%
baby_names.table(10)
# Out:
# <h1></h1>
#
#
#
#
#
# <div class="info_items">Viewing 10 of 1.0 million rows / 7 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">Unnamed: 0</div>
#             <div class="data_type">1 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Id</div>
#             <div class="data_type">2 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Name</div>
#             <div class="data_type">3 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Year</div>
#             <div class="data_type">4 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Gender</div>
#             <div class="data_type">5 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">State</div>
#             <div class="data_type">6 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">Count</div>
#             <div class="data_type">7 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='11349'>11349
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='11350'>11350
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Emma'>Emma
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2004'>2004
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='F'>F
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='AK'>AK
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='62'>62
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='11350'>11350
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='11351'>11351
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Madison'>Madison
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2004'>2004
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='F'>F
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='AK'>AK
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='48'>48
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='11351'>11351
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='11352'>11352
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Hannah'>Hannah
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2004'>2004
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='F'>F
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='AK'>AK
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='46'>46
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='11352'>11352
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='11353'>11353
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Grace'>Grace
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2004'>2004
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='F'>F
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='AK'>AK
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='44'>44
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='11353'>11353
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='11354'>11354
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Emily'>Emily
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2004'>2004
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='F'>F
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='AK'>AK
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='41'>41
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='11354'>11354
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='11355'>11355
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Abigail'>Abigail
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2004'>2004
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='F'>F
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='AK'>AK
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='37'>37
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='11355'>11355
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='11356'>11356
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='Olivia'>Olivia
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2004'>2004
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='F'>F
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='AK'>AK
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='33'>33
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='11356'

# %% [markdown]
# # Delete the column 'Unnamed: 0' and 'Id'

# %%
baby_names = baby_names.drop("Unnamed: 0", "Id")

# %%
baby_names.table(5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-e3c19713dd04> in <module>
# ----> 1 baby_names.table(5)
#
# ~/.local/lib/python3.6/site-packages/optimus/helpers/decorators.py in wrapper(self, *args, **kwargs)
#      14     def decorator(func):
#      15         @wraps(func)
# ---> 16         def wrapper(self, *args, **kwargs):
#      17             return func(self, *args, **kwargs)
#      18
#
# ~/.local/lib/python3.6/site-packages/optimus/dataframe/extension.py in table(self, limit, columns)
#     332     for i in dtypes:
#     333         for j in columns:
# --> 334             if i[0] == j:
#     335                 final_columns.append(i)
#     336
#
# ~/.local/lib/python3.6/site-packages/optimus/helpers/decorators.py in wrapper(self, *args, **kwargs)
#      14     def decorator(func):
#      15         @wraps(func)
# ---> 16         def wrapper(self, *args, **kwargs):
#      17             return func(self, *args, **kwargs)
#      18
#
# ~/.local/lib/python3.6/site-packages/optimus/dataframe/extension.py in table_html(self, limit, columns)
#     313
#     314     :return:
# --> 315     """
#     316
#     317     columns = parse_columns(self, columns)
#
# ~/.local/lib/python3.6/site-packages/pyspark/sql/dataframe.py in count(self)
#     520         2
#     521         """
# --> 522         return int(self._jdf.count())
#     523
#     524     @ignore_unicode_prefix
#
# ~/.local/lib/python3.6/site-packages/py4j/java_gateway.py in __call__(self, *args)
#    1253             proto.END_COMMAND_PART
#    1254
# -> 1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
#    1257             answer, self.gateway_client, self.target_id, self.name)
#
# ~/.local/lib/python3.6/site-packages/py4j/java_gateway.py in send_command(self, command, retry, binary)
#     983         connection = self._get_connection()
#     984         try:
# --> 985             response = connection.send_command(command)
#     986             if binary:
#     987                 return response, self._create_connection_guard(connection)
#
# ~/.local/lib/python3.6/site-packages/py4j/java_gateway.py in send_command(self, command)
#    1150
#    1151         try:
# -> 1152             answer = smart_decode(self.stream.readline()[:-1])
#    1153             logger.debug("Answer received: {0}".format(answer))
#    1154             if answer.startswith(proto.RETURN_MESSAGE):
#
# /opt/conda/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# KeyboardInterrupt:

# %% [markdown]
# #  Are there more male or female names in the dataset?

# %%
baby_names.groupby("Gender").count().orderBy("count").table()
# Out:
# <h1></h1>
#
#
#
#
#
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">2 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">Gender</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">count</div>
#             <div class="data_type">2 (bigint)</div>
#             <div class="data_type">
#
#                 not nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='M'>M
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='457549'>457549
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='F'>F
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='558846'>558846
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 2 of 2 rows / 2 columns</div>
# <div class="info_items">2 partition(s)</div>

# %% [markdown]
# # Group the dataset by name and assign to names

# %%
baby_names = baby_names.drop("Year")

# %%
names = baby_names.groupby("Name").sum().cols.rename("sum(Count)","count")

# %%
names.table(5)
# Out:
# <h1></h1>
#
#
#
#
#
# <div class="info_items">Viewing 5 of 17632 rows / 2 columns</div>
# <div class="info_items">200 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">Name</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">count</div>
#             <div class="data_type">2 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Kiana'>Kiana
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5965'>5965
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Alayna'>Alayna
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='14171'>14171
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Ember'>Ember
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='3181'>3181
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Tyler'>Tyler
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='129989'>129989
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Maddox'>Maddox
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='20716'>20716
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 5 of 17632 rows / 2 columns</div>
# <div class="info_items">200 partition(s)</div>

# %%
print(f'Columns: {op.profiler.dataset_info(names)["cols_count"]}', 
      f'Rows: {op.profiler.dataset_info(names)["rows_count"]}')
# Out:
# Columns: 2 Rows: 17632

# %%
names.sort(desc("count")).table(10)
# Out:
# <h1></h1>
#
#
#
#
#
# <div class="info_items">Viewing 10 of 17632 rows / 2 columns</div>
# <div class="info_items">141 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">Name</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">count</div>
#             <div class="data_type">2 (bigint)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Jacob'>Jacob
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='242874'>242874
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Emma'>Emma
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='214852'>214852
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Michael'>Michael
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='214405'>214405
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Ethan'>Ethan
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='209277'>209277
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Isabella'>Isabella
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='204798'>204798
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='William'>William
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='197894'>197894
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Joshua'>Joshua
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='191551'>191551
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Sophia'>Sophia
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='191446'>191446
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Daniel'>Daniel
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='191440'>191440
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Emily'>Emily
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='190318'>190318
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 10 of 17632 rows / 2 columns</div>
# <div class="info_items">141 partition(s)</div>

# %% [markdown]
# # How many different names exist in the dataset?

# %%
names.count()
# Out:
# 17632

# %% [markdown]
# # What is the name with most occurrences?

# %%
names.sort(desc("count")).select("Name").table(1)
# Out:
# <h1></h1>
#
#
#
#
#
# <div class="info_items">Viewing 1 of 17632 rows / 1 columns</div>
# <div class="info_items">141 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">Name</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='Jacob'>Jacob
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 1 of 17632 rows / 1 columns</div>
# <div class="info_items">141 partition(s)</div>

# %% [markdown]
# # How many different names have the least occurrences?

# %%
min_oc = names.cols.min("count") # This will give you the min ocurrence for names
names.where(col("count") == min_oc).count()
# Out:
# 2578

# %% [markdown]
# # What is the median name occurrence?

# %%
median_oc = names.approxQuantile("count", [0.5], relativeError=0)[0] # This will give you the median ocurrence for names
median_oc
# Out:
# 49.0

# %% [markdown]
# # What is the standard deviation of names?

# %%
names.cols.std("count")
# Out:
# 11006.06947

# %% [markdown]
# # Get a summary with the mean, min, max, std and quartiles.

# %%
names.select("count").describe().table()
# Out:
# <h1></h1>
#
#
#
#
#
# <div class="info_items">Viewing 5 of 5 rows / 2 columns</div>
# <div class="info_items">1 partition(s)</div>
#
# <table class="optimus_table">
#     <thead>
#     <tr>
#
#         <th>
#             <div class="column_name">summary</div>
#             <div class="data_type">1 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#         <th>
#             <div class="column_name">count</div>
#             <div class="data_type">2 (string)</div>
#             <div class="data_type">
#
#                 nullable
#
#             </div>
#         </th>
#
#     </tr>
#
#     </thead>
#     <tbody>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='count'>count
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='17632'>17632
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='mean'>mean
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='2008.932168784029'>2008.932168784029
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='stddev'>stddev
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='11006.069467890566'>11006.069467890566
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='min'>min
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='5'>5
#             </div>
#         </td>
#
#     </tr>
#
#     <tr>
#
#         <td>
#             <div class=" "
#                  title='max'>max
#             </div>
#         </td>
#
#         <td>
#             <div class=" "
#                  title='242874'>242874
#             </div>
#         </td>
#
#     </tr>
#
#     </tbody>
# </table>
#
#
# <div class="info_items">Viewing 5 of 5 rows / 2 columns</div>
# <div class="info_items">1 partition(s)</div>

# %%
names.approxQuantile("count",[0.25,0.5,0.75], relativeError=0)
# Out:
# [11.0, 49.0, 337.0]
